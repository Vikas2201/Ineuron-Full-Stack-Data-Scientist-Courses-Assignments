# %% [markdown]
# ### Q1. You are given two strings s and t. String t is generated by randomly shuffling string s and then adding one more letter at a random position. Return the letter that was added to t.
#
# Examples
#
# find_the_difference(&quot;abcd&quot;, &quot;abcde&quot;) ➞ &quot;e&quot;
#
# find_the_difference(&quot;&quot;, &quot;y&quot;) ➞ &quot;y&quot;
#
# find_the_difference(&quot;ae&quot;, &quot;aea&quot;) ➞ &quot;a&quot;

# %%
def find_the_difference(s,t):
    sum1 , sum2 = 0 , 0
    for i in s:
        sum1 += ord(i)
    for i in t:
        sum2 += ord(i)
    diff = abs(sum1 - sum2)
    return chr(diff)

# %%
find_the_difference("abcd", "abcde")
# Out:
# 'e'

# %%
find_the_difference("", "y")
# Out:
# 'y'

# %%
find_the_difference("ae", "aea")
# Out:
# 'a'

# %% [markdown]
# ### Q2. Given a function that accepts unlimited arguments, check and count how many data types are in those arguments. Finally return the total in a list.
#
# List order is: [int, str, bool, list, tuple, dictionary]
#
# Examples
#
# count_datatypes(1, 45, &quot;Hi&quot;, False) ➞ [2, 1, 1, 0, 0, 0]
#
# count_datatypes([10, 20], (&quot;t&quot;, &quot;Ok&quot;), 2, 3, 1) ➞ [3, 0, 0, 1, 1, 0]
#
# count_datatypes(&quot;Hello&quot;, &quot;Bye&quot;, True, True, False, {&quot;1&quot;: &quot;One&quot;, &quot;2&quot;: &quot;Two&quot;}, [1,3], {&quot;Brayan&quot;: 18}, 25, 23) ➞ [2, 2, 3, 1, 0, 2]
#
# count_datatypes(4, 21, (&quot;ES&quot;, &quot;EN&quot;), (&quot;a&quot;, &quot;b&quot;), False, [1, 2, 3], [4, 5, 6]) ➞ [2, 0, 1, 2, 2, 0]

# %%
def count_datatypes(*args):
    count_list = [0,0,0,0,0,0]
    for i in args:
        if type(i) == int:
            count_list[0] += 1
        elif type(i) == str:
            count_list[1] += 1
        elif type(i) == bool:
            count_list[2] += 1
        elif type(i) == list:
            count_list[3] += 1
        elif type(i) == tuple:
            count_list[4] += 1
        elif type(i) == dict:
            count_list[5] += 1
    return count_list

# %%
count_datatypes(1, 45, "Hi", False)
# Out:
# [2, 1, 1, 0, 0, 0]

# %%
count_datatypes("Hello", "Bye", True, True, False, {"1": "One", "2": "Two"}, [1,3], {"Brayan": 18}, 25, 23)
# Out:
# [2, 2, 3, 1, 0, 2]

# %%
count_datatypes(4, 21, ("ES", "EN"), ("a", "b"), False, [1, 2, 3], [4, 5, 6])
# Out:
# [2, 0, 1, 2, 2, 0]

# %% [markdown]
# ### Q3. A Fibonacci string is a precedence of the Fibonacci series. It works with any two characters of the English alphabet (as opposed to the numbers 0 and 1 in the Fibonacci series) as the initial items and concatenates them together as it progresses in a similar fashion as the Fibonacci series.
#
# Examples
#
# fib_str(3, [&quot;j&quot;, &quot;h&quot;]) ➞ &quot;j, h, hj&quot;
#
# fib_str(5, [&quot;e&quot;, &quot;a&quot;]) ➞ &quot;e, a, ae, aea, aeaae&quot;
#
# fib_str(6, [&quot;n&quot;, &quot;k&quot;]) ➞ &quot;n, k, kn, knk, knkkn, knkknknk&quot;

# %%
def fib_str(n,lt):
    f1 , f2 = lt[0] , lt[1]
    for i in range(2,n):
        f = f2 + f1
        lt.append(f)
        f1 , f2 = f2 , f
    return ', '.join(lt)

# %%
fib_str(3, ["j", "h"])
# Out:
# 'j, h, hj'

# %%
fib_str(5, ["e", "a"])
# Out:
# 'e, a, ae, aea, aeaae'

# %%
fib_str(6, ["n", "k"])
# Out:
# 'n, k, kn, knk, knkkn, knkknknk'

# %% [markdown]
# ### Q4. Given an integer between 0 and 26, make a variable (self.answer). That variable would be assigned to a string in this format: &quot;nines:your answer, threes:your answer, ones:your answer&quot; You need to find out how many ones, threes, and nines it would at least take for the number of each to add up to the given integer when multiplied by one, three or nine (depends).
#
# Examples
#
# ones_threes_nines(10) ➞ &quot;nines:1, threes:0, ones:1&quot;
#
# ones_threes_nines(15) ➞ &quot;nines:1, threes:2, ones:0&quot;
#
# ones_threes_nines(22) ➞ &quot;nines:2, threes:1, ones:1&quot;

# %%
def ones_threes_nines(n):
    answer = {'nines':0,'threes' : 0,'ones':0 }
    while(n > 0):
        if n // 9 > 0:
            answer['nines'] = n // 9
            n = n % 9
        elif n // 3 > 0:
            answer['threes'] = n // 3
            n = n % 3
        else:
            answer['ones'] = n // 1
            n = n % 1
    ans = ""
    for k,v in answer.items():
        ans = ans + k + ":" + str(v) + " "
    return ', '.join(ans.strip().split())

# %%
ones_threes_nines(10)
# Out:
# 'nines:1, threes:0, ones:1'

# %%
ones_threes_nines(15)
# Out:
# 'nines:1, threes:2, ones:0'

# %%
ones_threes_nines(22)
# Out:
# 'nines:2, threes:1, ones:1'

# %% [markdown]
# ### Q5. The Fibonacci sequence is a classic use case for recursive functions since the value of the sequence at a given index is dependent on the sum of the last two values. However, the recursion tree created by solving the Fibonacci sequence recursively can grow quite fast. Therefore it can be important to think about the implications of running a function recursively. Depending on the size of n needed and the capabilities of the system in question you might want to take a different approach. Write a non-recursive function that takes an integer n and returns the Fibonacci sequence&#39;s value at index n.
#
# Examples
#
# fib(6) ➞ 8
# #0 + 1 = 1, 1 + 1 = 2, 1 + 2 = 3, 2 + 3 = 5, 3 + 5 = 8
#
# fib(1) ➞ 1
#
# fib(2) ➞ 1

# %%
def fib(n):
    f1 , f2 = 0 , 1
    count = 0
    while count <= n:   
        count+=1
        if count > n:
            return f1
        f = f1 + f2            
        f1,f2 = f2, f

# %%
fib(1)
# Out:
# 1

# %%
fib(6)
# Out:
# 8

# %%
fib(2)
# Out:
# 1
